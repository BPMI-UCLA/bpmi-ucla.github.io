# %%
import os

# %%
root_dir = "images/impressions-covid/BPMISubmissions"
title_dir = "post-title.txt"
intro = "author-intro.txt"
feature_image = "feature-image.jpg"
submissions = "list.txt"
post_image = "covid-post-img.jpg"
post_file_path = "/Users/jackzhao/Downloads/BPMISubmissions/posts"

# %%
os.chdir("/Users/jackzhao/Downloads/BPMISubmissions")

for project in os.listdir("."):
    if project.startswith(".") or os.path.isfile(project) or project == "posts":
        continue
    os.chdir(project)
    print(os.getcwd())

    for file in os.listdir("."):
        print("  - " + file)
    os.chdir("..")
# Out:
# /Users/jackzhao/Downloads/BPMISubmissions/Xiwei
#   - list.txt
#   - author-info.txt
#   - feature-image.png
#   - post-title.txt
#   - youtube.txt
#   - XiWei.txt
# /Users/jackzhao/Downloads/BPMISubmissions/ShelterMadefromMetalNet
#   - list.txt
#   - ShelterMadefromMetalNet.txt
#   - author-info.txt
#   - feature-image.png
#   - post-title.txt
#   - p3.jpg
#   - p2.jpg
#   - p1.jpg
# /Users/jackzhao/Downloads/BPMISubmissions/PandemicFossils
#   - list.txt
#   - PandemicFossils2.jpeg
#   - feature-image.jpg
#   - PandemicFossils3.jpeg
#   - post-title.txt
#   - author-intro.txt
#   - PandemicFossils1.jpeg
#   - PandemicFossils.txt
# /Users/jackzhao/Downloads/BPMISubmissions/DateInQuarantine
#   - list.txt
#   - DateInQuarantine.txt
#   - author-info.txt
#   - feature-image.png
#   - post-title.txt
#   - DateInQuarantine.png
# /Users/jackzhao/Downloads/BPMISubmissions/IWantToGoOutside
#   - list.txt
#   - author-info.txt
#   - feature-image.png
#   - post-title.txt
#   - p3.png
#   - p2.png
#   - p1.png
#   - p5.png
#   - p4.png
#   - p6.png
#   - IWantToGoOutside.txt
# /Users/jackzhao/Downloads/BPMISubmissions/AnonymousLoveToElsewhereAndHere
#   - list.txt
#   - Anonymousloveto1.jpeg
#   - AnonymousLoveToElsewhereAndHere.txt
#   - feature-image.png
#   - feature-image.jpg
#   - post-title.txt
#   - author-intro.txt
#   - Anonymousloveto2.jpeg
#   - Anonymousloveto3.JPG
#   - Anonymousloveto5.JPG
#   - Anonymousloveto4.jpg
#   - Anonymousloveto6.JPG
# /Users/jackzhao/Downloads/BPMISubmissions/BreakCrisis
#   - list.txt
#   - author-info.txt
#   - feature-image.png
#   - post-title.txt
#   - video.mp4
#   - BreakCrisis.txt
# /Users/jackzhao/Downloads/BPMISubmissions/ThePrivilegeOfQuarantine2020
#   - Luciana_Acuña 12.jpg
#   - list.txt
#   - Luciana_Acuña 10.jpg
#   - feature-image.png
#   - post-title.txt
#   - ThePrivilegeOfQuarantine2020.txt
#   - author-intro.txt
#   - Luciana_Acuña 7.jpg
#   - Luciana_Acuña 5.jpg
#   - Luciana_Acuña 1.jpg
# /Users/jackzhao/Downloads/BPMISubmissions/PickledStripper
#   - PickledStripper.txt
#   - list.txt
#   - feature-image.jpg
#   - post-title.txt
#   - Tange_Kayla_PickledStripper-Lifethroughpickledcoloredglasses_2020.jpg
#   - author_intro.txt
# /Users/jackzhao/Downloads/BPMISubmissions/CoronaTime
#   - CoronaTime.txt
#   - feature-image.png
#   - post-title.txt
#   - youtube.txt
#   - author-intro.txt
# /Users/jackzhao/Downloads/BPMISubmissions/Corona
#   - list.txt
#   - feature-image.png
#   - post-title.txt
#   - p3.jpg
#   - Corona.txt
#   - author-intro.txt
#   - p2.jpg
#   - p1.jpg
#   - p5.jpg
#   - p4.jpg
#   - p6.jpg
# /Users/jackzhao/Downloads/BPMISubmissions/TheSenseOfDistance
#   - list.txt
#   - feature-image.jpg
#   - post-title.txt
#   - author-intro.txt
#   - TheSenseOfDistance.txt
#   - TheSenseOfDistance.jpg
# /Users/jackzhao/Downloads/BPMISubmissions/NCC
#   - list.txt
#   - author-info.txt
#   - feature-image.png
#   - post-title.txt
#   - p3.jpg
#   - p2.jpg
#   - p1.jpg
#   - p4.jpg
#   - NCC.txt
# /Users/jackzhao/Downloads/BPMISubmissions/CoronaTeaTime
#   - list.txt
#   - CoronaSharingTime.jpg
#   - CoronaTeaTime.txt
#   - feature-image.jpg
#   - post-title.txt
#   - CoronaTeaTime.jpg
#   - author-intro.txt
#   - CoronaMealTime.jpg
# /Users/jackzhao/Downloads/BPMISubmissions
#   - list.txt
#   - feature-image.jpg
#   - post-title.txt
#   - DieForWhat.jpg
#   - author-intro.txt
#   - CovidChristmas.txt
# /Users/jackzhao/Downloads/BPMISubmissions/DreakuriYumi
#   - DreakuriYumi1.jpg
#   - DreakuriYumi.txt
#   - DreakuriYumi2.jpg
#   - list.txt
#   - feature-image.jpg
#   - post-title.txt
#   - author-intro.txt
# /Users/jackzhao/Downloads/BPMISubmissions/ZoomFatigue
#   - list.txt
#   - feature-image.jpg
#   - post-title.txt
#   - author-intro.txt
#   - ZoomFatigue.txt
#   - ZoomFatigue.jpg
# /Users/jackzhao/Downloads/BPMISubmissions/COVID
#   - Intensive.jpg
#   - Testing.jpg
#   - list.txt
#   - All.jpg
#   - feature-image.jpg
#   - post-title.txt
#   - author-intro.txt
#   - Fatigue.jpg
#   - COVID.txt
#   - Police.jpg
#   - The.jpg
# /Users/jackzhao/Downloads/BPMISubmissions/Masker
#   - Masker.txt
#   - list.txt
#   - author-info.txt
#   - Masker.jpeg
#   - feature-image.png
#   - post-title.txt
# /Users/jackzhao/Downloads/BPMISubmissions/CovidArtifact
#   - list.txt
#   - feature-image.jpg
#   - post-title.txt
#   - CA6.jpg
#   - author-intro.txt
#   - CA5.jpg
#   - CA4.jpg
#   - CA3.jpg
#   - CA2.jpg
#   - CA.jpg
#   - CovidArtifact.txt
# /Users/jackzhao/Downloads/BPMISubmissions/TakingPrecaution
#   - list.txt
#   - feature-image.jpg
#   - post-title.txt
#   - author-intro.txt
#   - TakingPrecaution.jpg
#   - TakingPrecaution.txt
# /Users/jackzhao/Downloads/BPMISubmissions/PandemicPoetry
#   - list.txt
#   - feature-image.png
#   - post-title.txt
#   - PandemicPoetry.txt
#   - author-intro.txt
# /Users/jackzhao/Downloads/BPMISubmissions/AMapofQuarantine
#   - list.txt
#   - AMapofQuarantine.txt
#   - feature-image.png
#   - post-title.txt
#   - youtube.txt
#   - author-intro.txt
# /Users/jackzhao/Downloads/BPMISubmissions/Uncanny
#   - FatherAndSon.jpg
#   - Isolation.jpg
#   - list.txt
#   - feature-image.jpg
#   - post-title.txt
#   - SocialDisatnce.jpg
#   - author-intro.txt
#   - ArtExhibitionHall.jpg
#   - Uncanny.txt
# /Users/jackzhao/Downloads/BPMISubmissions/DoYouWantCottonCandy
#   - list.txt
#   - feature-image.png
#   - post-title.txt
#   - DoYouWantCottonCandy.txt
#   - author-intro.txt
#   - Picture1.png
# /Users/jackzhao/Downloads/BPMISubmissions/DisneyPrincesses
#   - list.txt
#   - author-info.txt
#   - feature-image.png
#   - post-title.txt
#   - DisneyPrincesses.txt
#   - p3.jpg
#   - p2.jpg
#   - p1.jpg
#   - p4.jpg
# /Users/jackzhao/Downloads/BPMISubmissions/Emotions
#   - EGO.jpg
#   - list.txt
#   - feature-image.png
#   - post-title.txt
#   - author-intro.txt
#   - SADNESS.jpg
#   - Melancholy.jpg
#   - Emotions.txt

# %%
print(os.path.join(root_dir, post_image))
# Out:
# images/impressions-covid/BPMISubmissions/covid-post-img.jpg

# %%
template = f'''
---
title: "%(title)s"
date: 2021-02-13T12:00:00
featureImage: %(feature_image)s
postImage: {os.path.join(root_dir, post_image)}
draft: false
---

## About Author

%(author_intro)s

%(artwork_intro)s

%(artworks)s
'''

artwork = "!\[%(name)s\](%(path)s)"  
youtube_artwork = "{{< youtube %s >}}"

# %%
os.chdir("/Users/jackzhao/Downloads/BPMISubmissions")

for project in os.listdir("."):
    
    artwork = "!\[%(name)s\](%(path)s)"  
    youtube_artwork = "{{< youtube %s >}}"

    if project.startswith(".") or os.path.isfile(project) or project == "posts":
        continue
    os.chdir(project)
    print(os.getcwd())
    

    works = []
    try:
        lists = open(submissions, "r")
        works = [x.strip() for x in lists.readlines()]
    except:
        works.append('youtube.txt')
    
    title = ''
    title_file = open(title_dir, "r")
    title = title_file.readline().strip()
    print (f" - Title: {title}")
    
    author_intro = ''
    try:
        author_file = open (intro, "r")
    except:
        author_file = open ("author-info.txt", "r")
    author_intro = ''.join(author_file.readlines())
    print(f" - Author:{author_intro[:20]}")
    
    artwork_intro = ''
    try:
        artwork_file = open(f"{project}.txt")
        artwork_intro = "## About Artwork\n" + ''.join(artwork_file.readlines())
    except:
        print(" - Oh Shit")
    
    artwork_strings = ""
    temp = []
    for artwork in works:
        if artwork == '':
            continue
        elif artwork == 'youtube.txt':
            f = open(artwork, 'r')
            tmp = f.readline().split('/')[-1]
            print('tmp: ', tmp)
            temp.append("{{< youtube %s >}}" % tmp)
            break
        elif '.txt' in artwork:
            content = open(artwork, "r")
            artwork_strings = ''.join(content.readlines())
            break
        else:
            n = artwork.split('.')[0]
            p = os.path.join(root_dir, project, artwork)
            temp.append("![" + n + "](../../" + p + ")")

    if temp != []:
        artwork_strings = '\n\n'.join(temp)

    
    feature_image = ""
    for file in os.listdir("."):
        if "feature" in file:
            feature_image = file
            break
    
    print(f"Creating...", os.path.join(post_file_path, project + ".md"))
    post_buffer = open(os.path.join(post_file_path, project + ".md"), "w")
    post_content = template % {
        'title':title,
        'author_intro': author_intro,
        'artwork_intro': artwork_intro,
        'artworks': artwork_strings,
        'feature_image': os.path.join(root_dir, project, feature_image)
    }
    print ('========') 
    print(post_content)
    
    print ('========') 
    post_buffer.write(post_content)
    post_buffer.close()
    os.chdir("..")
# Out:
# /Users/jackzhao/Downloads/BPMISubmissions/Xiwei
#  - Title: Xi Wei
#  - Author:**Artist Name:** Yih
# Creating... /Users/jackzhao/Downloads/BPMISubmissions/posts/Xiwei.md
# ========
#
# ---
# title: "Xi Wei"
# date: 2021-02-13T12:00:00
# featureImage: images/impressions-covid/BPMISubmissions/Xiwei/feature-image.png
# postImage: images/impressions-covid/BPMISubmissions/covid-post-img.jpg
# draft: false
# ---
#
# ## About Author
#
# **Artist Name:** Yihua He
#
# ### Introduction
# Yihua is a student from Fudan University in China.
#
# ## About Artwork
# This is a story set in the context of the beginning of the coronavirus outbreak in China.
#
#
#
# ========
# /Users/jackzhao/Downloads/BPMISubmissions/ShelterMadefromMetalNet
#  - Title: Shelter Made from Metal Net
#  - Author:**Artist Name:** Ste
# Creating... /Users/jackzhao/Downloads/BPMISubmissions/posts/ShelterMadefromMetalNet.md
# ========
#
# ---
# title: "Shelter Made from Metal Net"
# date: 2021-02-13T12:00:00
# featureImage: images/impressions-covid/BPMISubmissions/ShelterMadefromMetalNet/feature-image.png
# postImage: images/impressions-covid/BPMISubmissions/covid-post-img.jpg
# draft: false
# ---
#
# ## About Author
#
# **Artist Name:** Stefania
#
# ### Introduction
# Stefania graduated from the Academia Belle Arti Di Brera
#
#
# ## About Artwork
# Masks increased our distance with each other. Our hearts are as if encircled by metal nets. The color red represents sunshine, passion, love and hope. With this blooming red flower, a sign of hope is coming our way.
#
# ![p1](../../images/impressions-covid/BPMISubmissions/ShelterMadefromMetalNet/p1.jpg)
#
# ![p2](../../images/impressions-covid/BPMISubmissions/ShelterMadefromMetalNet/p2.jpg)
#
# ![p3](../../images/impressions-covid/BPMISubmissions/ShelterMadefromMetalNet/p3.jpg)
#
# ========
# /Users/jackzhao/Downloads/BPMISubmissions/PandemicFossils
#  - Title: Pandemic Fossils
#  - Author:**Artist Name:** Ken
# Creating... /Users/jackzhao/Downloads/BPMISubmissions/posts/PandemicFossils.md
# ========
#
# ---
# title: "Pandemic Fossils"
# date: 2021-02-13T12:00:00
# featureImage: images/impressions-covid/BPMISubmissions/PandemicFossils/feature-image.jpg
# postImage: images/impressions-covid/BPMISubmissions/covid-post-img.jpg
# draft: false
# ---
#
# ## About Author
#
# **Artist Name:** Ken Goldman
#
# ### Introduction
# Ken Goldman is an artist based in Israel. His art is filled with insider references innuendos and humor. While at times seemingly irreverent - the works are inspired by and react to; traditional, texts, and rituals. He sees his art as a vehicle for promoting dialogue, a catalyst for provoking people into re-evaluating their preconceptions, a medium for breaking down stereotypes, and an opportunity for people of all walks of life to connect with theirs and others' religion, culture, and history.
#
# ## About Artwork
# "Pandemic Fossils"- carved local stone / limestone - 2020
#
# Confronted by endless Pandemic Litters polluting the area made me think what future archaeologists will make of the strata they uncover form these pandemic times.
#
#
# ![PandemicFossils1](../../images/impressions-covid/BPMISubmissions/PandemicFossils/PandemicFossils1.jpeg)
#
# ![PandemicFossils2](../../images/impressions-covid/BPMISubmissions/PandemicFossils/PandemicFossils2.jpeg)
#
# ![PandemicFossils3](../../images/impressions-covid/BPMISubmissions/PandemicFossils/PandemicFossils3.jpeg)
#
# ========
# /Users/jackzhao/Downloads/BPMISubmissions/DateInQuarantine
#  - Title: My Date in Quarantine
#  - Author:**Artist Name:** Yum
# Creating... /Users/jackzhao/Downloads/BPMISubmissions/posts/DateInQuarantine.md
# ========
#
# ---
# title: "My Date in Quarantine"
# date: 2021-02-13T12:00:00
# featureImage: images/impressions-covid/BPMISubmissions/DateInQuarantine/feature-image.png
# postImage: images/impressions-covid/BPMISubmissions/covid-post-img.jpg
# draft: false
# ---
#
# ## About Author
#
# **Artist Name:** Yumeng Zhuang
#
# ### Introduction
# Yumeng is part of UCLA Class of 2021, an art lover majoring in Physics.
#
# ## About Artwork
# In the United States, it has been about ten months since the quarantine threw our lives out of the familiar track. I think my relationships with other people suffered the most, and many people started to have pets to fill in the blanks and welcome them as part of their families. This painting features my friend’s cat Potato, who I met for a few times on several “dates”. That he comes from another family deepens the novelty I felt each time I met him, and this time I fell for his new bow tie and his innocent pride. I hope that when the pandemic is over, we can still remember these moving moments when we make interspecies connections and take good care of our companions through the hard times.
#
# ![DateInQuarantine](../../images/impressions-covid/BPMISubmissions/DateInQuarantine/DateInQuarantine.png)
#
# ========
# /Users/jackzhao/Downloads/BPMISubmissions/IWantToGoOutside
#  - Title: I Want To Go Outside
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-afeeaaa9a3d0> in <module>
#      25
#      26     author_intro = ''
# ---> 27     author_file = open (intro, "r")
#      28     author_intro = ''.join(author_file.readlines())
#      29     print(f" - Author:{author_intro[:20]}")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'author-intro.txt'
